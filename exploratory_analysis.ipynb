# %%
import pandas as pd
import matplotlib.pyplot as plt


df_sectors = pd.read_csv('data/processed/sector_returns_processed.csv', index_col=0, parse_dates=True)
df_spx = pd.read_csv('data/processed/spx_processed.csv', index_col=0, parse_dates=True)


print("First 5 rows of Sector Returns:")
display(df_sectors.head())


print("\nSummary Statistics for Sectors:")
display(df_sectors.describe())
# Out:
# First 5 rows of Sector Returns:
#            ticker    return       name
# date
# 2000-01-03    XLB       NaN  materials
# 2000-01-04    XLB -0.009627  materials
# 2000-01-05    XLB  0.041312  materials
# 2000-01-06    XLB  0.025671  materials
# 2000-01-07    XLB -0.000569  materials
# Summary Statistics for Sectors:
#              return
# count  64078.000000
# mean       0.000464
# std        0.014267
# min       -0.201412
# 25%       -0.005823
# 50%        0.000814
# 75%        0.007138
# max        0.164747

# %%
plt.figure(figsize=(10, 6))

df_sectors['return'].dropna().hist(bins=100, color='skyblue', edgecolor='black')

plt.title('Distribution of Daily Sector Returns (2000 - Present)')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()
